# %% [markdown]
# # Importando

# %%
pip install Jinja2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options

# %% [markdown]
# # Raspagem de dados

# %% [markdown]
# # Todos da serie A (2014 - 2024)

# %%
import os
import time
import pandas as pd
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager

# Temporadas e URLs correspondentes
temporadas_urls = {
    "2025": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2024",
    "2024": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2023",
    "2023": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2022",
    "2022": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2021",
    "2021": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2020",
    "2020": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2019",
    "2019": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2018",
    "2018": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2017",
    "2017": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2016",
    "2016": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2015",
    "2015": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2014",
    "2014": "https://www.transfermarkt.com.br/campeonato-brasileiro-serie-a/startseite/wettbewerb/BRA1/plus/?saison_id=2013"
}

# Setup navegador headless
options = Options()
options.add_argument("--headless")
options.add_argument("--disable-gpu")
options.add_argument("--no-sandbox")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)

# Caminho para a pasta 'dados'
dados_pasta = "dados/Todos_serieA"
os.makedirs(dados_pasta, exist_ok=True)

for temporada, url in temporadas_urls.items():
    print(f"Coletando dados da temporada {temporada}...")
    driver.get(url)
    time.sleep(5)

    soup = BeautifulSoup(driver.page_source, "html.parser")
    table = soup.find("table", class_="items")

    clubes_data = []
    if table:
        rows = table.find_all("tr", class_=["odd", "even"])
        for row in rows:
            cols = row.find_all("td")
            if len(cols) >= 7:
                clube = cols[1].text.strip()
                plantel = cols[2].text.strip()
                idade_media = cols[3].text.strip()
                estrangeiros = cols[4].text.strip()
                valor_medio = cols[5].text.strip()
                valor_total = cols[6].text.strip()

                clubes_data.append({
                    "Clube": clube,
                    "Plantel": plantel,
                    "ø Idade": idade_media,
                    "Estrangeiros": estrangeiros,
                    "ø Valor de Mercado": valor_medio,
                    "Valor de Mercado Total": valor_total
                })

    df = pd.DataFrame(clubes_data)
    df.to_csv(os.path.join(dados_pasta, f"valores_{temporada}.csv"), index=False, encoding="utf-8-sig")

    print(f"Temporada {temporada} finalizada com {len(df)} clubes.")

driver.quit()
# Out:
# Coletando dados da temporada 2025...
# Temporada 2025 finalizada com 20 clubes.
# Coletando dados da temporada 2024...
# Temporada 2024 finalizada com 20 clubes.
# Coletando dados da temporada 2023...
# Temporada 2023 finalizada com 20 clubes.
# Coletando dados da temporada 2022...
# Temporada 2022 finalizada com 20 clubes.
# Coletando dados da temporada 2021...
# Temporada 2021 finalizada com 20 clubes.
# Coletando dados da temporada 2020...
# Temporada 2020 finalizada com 20 clubes.
# Coletando dados da temporada 2019...
# Temporada 2019 finalizada com 20 clubes.
# Coletando dados da temporada 2018...
# Temporada 2018 finalizada com 20 clubes.
# Coletando dados da temporada 2017...
# Temporada 2017 finalizada com 20 clubes.
# Coletando dados da temporada 2016...
# Temporada 2016 finalizada com 20 clubes.
# Coletando dados da temporada 2015...
# Temporada 2015 finalizada com 20 clubes.
# Coletando dados da temporada 2014...
# Temporada 2014 finalizada com 20 clubes.

# %% [markdown]
# # Todos juntos

# %%
import os
import pandas as pd


pasta = os.path.join("dados", "Todos_serieA")


if not os.path.exists(pasta):
    print(f"A pasta '{pasta}' não foi encontrada.")
else:
    arquivos = sorted([arq for arq in os.listdir(pasta) if arq.endswith(".csv")])

    dfs = []

    for arquivo in arquivos:
        temporada = arquivo.split("_")[1].split(".")[0] 
        df = pd.read_csv(os.path.join(pasta, arquivo))
        df["Temporada"] = temporada.strip()
        dfs.append(df)

    df_final = pd.concat(dfs, ignore_index=True)

    df_final["Temporada"] = df_final["Temporada"].str.extract(r"(\d{4})")

  
    caminho_saida = os.path.join("dados", "todos_clubes_serieA.csv")
    
    df_final.to_csv(caminho_saida, index=False, encoding="utf-8-sig")

    print("✅ Arquivo 'todos_clubes_serieA.csv' criado com sucesso e coluna 'Temporada' limpa!")
# Out:
# ✅ Arquivo 'todos_clubes_serieA.csv' criado com sucesso e coluna 'Temporada' limpa!

# %% [markdown]
# # Transformando o arquivo BASE_FINAL xlsx em CSV
# * (O arquvio contém os dados dos valores do clube + pontos por temporada que foi feito no próprio excel com a formula procv)
# * Estando na aba 'Crud' la foi feito a organização dos dados para colocar na aba principal "todos_clubes_serieA"

# %%
import os
import pandas as pd

try:
    
    caminho_excel = os.path.join("dados", "BASE_FINAL.xlsx")

    df = pd.read_excel(caminho_excel, sheet_name="CLUBES")


    caminho_csv = os.path.join("dados", "todos_clubes_serieA_com_pontos.csv")

    
    df.to_csv(caminho_csv, index=False)

    print("CSV salvo com sucesso!")

except Exception as e:
    print(f"Ocorreu um erro: {e}")
# Out:
# CSV salvo com sucesso!

# %%
import pandas as pd
import os

file_path = os.path.join("dados", "BASE_FINAL.xlsx")

df = pd.read_excel(file_path, sheet_name="CLUBES")

df['Status_bin'] = df['Status'].apply(lambda x: 0 if x == 0 else 1)

df_treino = df[df['Temporada'] < 2025].copy()
df_prev = df[df['Temporada'] == 2025].copy()

print(df_treino.head())
print(df_prev.head())
# Out:
#               Clube  Plantel  ø Idade  Estrangeiros  ø Valor de Mercado  \
# 0         São Paulo       45       25             6                3.33
# 1       Corinthians       44       24             5                1.99
# 2            Santos       49       23             6                1.50
# 3  Atlético Mineiro       55       25             2                1.16
# 4        Fluminense       43       23             2                1.13
#
#    Valor de Mercado Total  Temporada  Pontos Situacao  Status  Status_bin
# 0                  149.65       2014      70     Top4     1.0           1
# 1                   87.55       2014      69     Top4     1.0           1
# 2                   73.40       2014      53     Top4     1.0           1
# 3                   63.85       2014      62     Top4     1.0           1
# 4                   48.80       2014      61   SerieA     2.0           1
#              Clube  Plantel  ø Idade  Estrangeiros  ø Valor de Mercado  \
# ...

# %%
from itertools import combinations

features = ['Plantel', 'ø Idade', 'Estrangeiros', 'ø Valor de Mercado', 'Valor de Mercado Total']

combinacoes = []
for i in range(1, len(features) + 1):
    combinacoes += list(combinations(features, i))

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
import numpy as np
import pandas as pd

# Definindo os modelos
models = {
    'Logit': LogisticRegression(),
    'RandomForest': RandomForestClassifier(),
    'SVM': SVC()
}

resultados_modelos = []

# Colunas que você deseja usar
colunas_necessarias = ['Plantel', 'Estrangeiros', 'Valor de Mercado Total']
combinacoes = [colunas_necessarias]  # Apenas uma combinação de variáveis neste caso

# Supondo que 'df_treino' seja o DataFrame com seus dados de treino
for comb in combinacoes:
    X = df_treino[comb]
    y = df_treino['Status_bin']  # A coluna alvo

    # Tratamento de valores ausentes
    if X.isnull().sum().any():
        X = X.fillna(X.mean())

    # Escalonamento
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    for nome_modelo, modelo in models.items():
        accs, maes, rmses = [], [], []

        for seed in range(50):
            X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=seed)
            modelo.fit(X_train, y_train)
            y_pred = modelo.predict(X_test)

            accs.append(accuracy_score(y_test, y_pred))
            maes.append(mean_absolute_error(y_test, y_pred))
            rmses.append(np.sqrt(mean_squared_error(y_test, y_pred)))

        resultados_modelos.append({
            'Features': ', '.join(comb),
            'Modelo': nome_modelo,
            'Acurácia Média': np.mean(accs),
            'MAE Médio': np.mean(maes),
            'RMSE Médio': np.mean(rmses)
        })

# Ordenando os resultados e mostrando os melhores modelos
df_resultados = pd.DataFrame(resultados_modelos)
top3 = df_resultados.sort_values(by='Acurácia Média', ascending=False).head(3)

print("🏆 Top 3 Modelos por Acurácia Média:\n")
print(top3[['Modelo', 'Features', 'Acurácia Média', 'MAE Médio', 'RMSE Médio']])

# Pegando a melhor combinação para o modelo Logit
logit_row = df_resultados[df_resultados['Modelo'] == 'Logit'].sort_values(by='Acurácia Média', ascending=False).iloc[0]
logit_comb = logit_row['Features'].split(', ')
# Out:
# 🏆 Top 3 Modelos por Acurácia Média:
#
#          Modelo                                       Features  \
# 0         Logit  Plantel, Estrangeiros, Valor de Mercado Total
# 2           SVM  Plantel, Estrangeiros, Valor de Mercado Total
# 1  RandomForest  Plantel, Estrangeiros, Valor de Mercado Total
#
#    Acurácia Média  MAE Médio  RMSE Médio
# 0        0.890000   0.110000    0.324764
# 2        0.880909   0.119091    0.338377
# 1        0.856818   0.143182    0.373422

# %% [markdown]
# * Tendo em vista que o modelo **Logit** apresentou a **melhor acurácia média (0.89)** entre os modelos avaliados, ele foi selecionado como o modelo principal para ser salvo e utilizado nas previsões.
#
# * É importante destacar que, por se tratar de um modelo de classificação, o **Logit (Regressão Logística)** **não utiliza o R² como métrica adequada** para avaliação. O R² é uma métrica de regressão, e sua aplicação nesse contexto pode gerar interpretações incorretas. Portanto, o foco da avaliação foi baseado principalmente na acurácia, no MAE e no RMSE.

# %%
import pickle
import os

X_treino_final = df_treino[logit_comb]
y_treino_final = df_treino['Status_bin']

scaler = StandardScaler()
X_treino_scaled = scaler.fit_transform(X_treino_final)

modelo_final = LogisticRegression(max_iter=1000)
modelo_final.fit(X_treino_scaled, y_treino_final)

os.makedirs('modelos', exist_ok=True)

with open('modelos/modelo_logit_status.pkl', 'wb') as f:
    pickle.dump(modelo_final, f)

with open('modelos/scaler_logit_status.pkl', 'wb') as f:
    pickle.dump(scaler, f)

print("✅ Modelo Logit e scaler salvos com sucesso!")
# Out:
# ✅ Modelo Logit e scaler salvos com sucesso!

# %% [markdown]
# # Previsão

# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import time
import io
from utils.processamento import fazer_previsao

def main():
    # Descrição sobre a ferramenta
    st.markdown("""
    <div class="card">
      <h3>📋 Sobre esta ferramenta</h3>
      <div style="padding: 0 10px;">
        Este aplicativo utiliza um modelo de <b>Machine Learning</b> (Regressão Logística) treinado com dados históricos do Brasileirão para prever se um clube será <b>rebaixado</b> ou <b>permanecerá</b> na Série A.<br>
        <b>O modelo considera três fatores principais:</b><br>
        • Tamanho do elenco<br>
        • Jogadores estrangeiros<br>
        • Valor de mercado
      </div>
    </div>
    """, unsafe_allow_html=True)

    # Seção para previsão em lote com arquivo CSV
    st.subheader("Previsão em Lote – Arquivo CSV")

    # Botão para baixar o template de arquivo CSV
    template_df = pd.DataFrame({
        "Plantel": [28, 24],
        "Estrangeiros": [4, 2],
        "Valor de Mercado Total": [85.0, 30.0]
    })
    csv_buffer = io.StringIO()
    template_df.to_csv(csv_buffer, index=False)
    csv_bytes = csv_buffer.getvalue().encode('utf-8')

    st.download_button(
        label="📥 Baixar exemplo de arquivo CSV",
        data=csv_bytes,
        file_name="template_dados_clubes.csv",
        mime="text/csv"
    )

    # Exibir o formato do arquivo CSV de exemplo
    with st.expander("Ver formato de exemplo (clique para abrir)"):
        st.dataframe(template_df, use_container_width=True)
        st.markdown("""
        O arquivo CSV deve conter as colunas exatas:<br>
        <code>Plantel, Estrangeiros, Valor de Mercado Total</code>
        """, unsafe_allow_html=True)

    # Uploader de arquivo CSV e exibição da previsão
    uploaded_file = st.file_uploader(
        "Faça upload de um arquivo CSV para previsão em lote",
        type=["csv"]
    )

    if uploaded_file is not None:
        df_csv = pd.read_csv(uploaded_file)
        st.info("Pré-visualização dos dados enviados:")
        st.dataframe(df_csv.head(), use_container_width=True)

        with st.spinner('Analisando dados do arquivo...'):
            previsoes, probabilidades = fazer_previsao(df_csv)
            df_csv["Probabilidade Rebaixamento (%)"] = [round(p[1]*100,1) for p in probabilidades]
            df_csv["Resultado"] = ["Rebaixado" if p[1] > 0.5 else "Não Rebaixado" for p in probabilidades]
        
        st.success("Resultados das previsões no arquivo:")
        st.dataframe(df_csv, use_container_width=True)

        # Gráfico de barras para o lote de previsões
        if "Probabilidade Rebaixamento (%)" in df_csv.columns and "Resultado" in df_csv.columns:
            fig_batch = px.bar(
                df_csv,
                x=df_csv.index.astype(str),
                y="Probabilidade Rebaixamento (%)",
                color="Resultado",
                title="Probabilidade de Rebaixamento dos Clubes (Arquivo)",
                labels={"x": "Clube na ordem do arquivo"}
            )
            st.plotly_chart(fig_batch, use_container_width=True)

        st.markdown("---")

    # Formulário para previsão de um clube específico
    col1, col2 = st.columns([1, 1])
    with col1:
        st.markdown("<h3 class='subheader'>Dados do Clube</h3>", unsafe_allow_html=True)
        with st.form(key="prediction_form"):
            nome_time = st.text_input("Nome do Clube", value="Meu Time")
            plantel = st.slider(
                "Número de Jogadores no Elenco", 
                min_value=15, max_value=50, value=25,
                help="A média de jogadores nos clubes da Série A é de aproximadamente 28 atletas"
            )
            estrangeiros = st.slider(
                "Número de Estrangeiros", 
                min_value=0, max_value=15, value=3,
                help="A média de estrangeiros nos clubes da Série A é de aproximadamente 4 atletas"
            )
            valor_mercado_total = st.slider(
                "Valor de Mercado (em milhões €)", 
                min_value=5.0, max_value=300.0, value=50.0, step=5.0,
                help="A média de valor de mercado dos clubes da Série A é de aproximadamente €85 milhões"
            )
            submit_button = st.form_submit_button(label="Analisar Risco de Rebaixamento")

    with col2:
        st.markdown("<h3 class='subheader'>Resultado da Análise</h3>", unsafe_allow_html=True)
        result_container = st.container()
        if submit_button:
            dados_entrada = {
                'Plantel': [plantel],
                'Estrangeiros': [estrangeiros],
                'Valor de Mercado Total': [valor_mercado_total]
            }
            dados_entrada_df = pd.DataFrame(dados_entrada)
            with st.spinner('Analisando dados...'):
                time.sleep(1)
                previsao, probabilidade = fazer_previsao(dados_entrada_df)
                prob_rebaixamento = probabilidade[0][1]
                resultado = 'Rebaixado' if prob_rebaixamento > 0.5 else 'Não Rebaixado'
                
                # Determinando a cor e a mensagem com base na probabilidade
                if prob_rebaixamento < 0.3:
                    cor = "green"
                    mensagem = "Baixo risco de rebaixamento"
                    emoji = "✅"
                elif prob_rebaixamento < 0.7:
                    cor = "orange"
                    mensagem = "Risco moderado de rebaixamento"
                    emoji = "⚠️"
                else:
                    cor = "red"
                    mensagem = "Alto risco de rebaixamento"
                    emoji = "🚨"

                with result_container:
                    st.markdown(f"""
                    <div style="background-color:{cor}; padding:20px; border-radius:10px; text-align:center; color:white;">
                        <h2>{nome_time}</h2>
                        <h2>{emoji} {resultado} {emoji}</h2>
                        <h4>{mensagem}</h4>
                        <h1 style="font-size:3rem;">{prob_rebaixamento:.1%}</h1>
                        <p>Probabilidade de Rebaixamento</p>
                    </div>
                    """, unsafe_allow_html=True)
                    
                    # Exibindo gráfico de pizza
                    st.markdown('<div style="display: flex; justify-content: center;">', unsafe_allow_html=True)
                    col_pizza = st.columns([1, 2, 1])[1]
                    with col_pizza:
                        fig = px.pie(
                            values=[prob_rebaixamento, 1-prob_rebaixamento],
                            names=['Rebaixamento', 'Permanência'],
                            hole=0.7,
                            color_discrete_sequence=['#FF5A5F', '#3D9970']
                        )
                        fig.update_layout(
                            title="Probabilidades",
                            height=300,
                            width=400,
                            margin=dict(l=20, r=20, t=30, b=0),
                            showlegend=True,
                            legend=dict(orientation="h", yanchor="bottom", y=-0.1, xanchor="center", x=0.5)
                        )
                        fig.add_annotation(
                            text=f"{prob_rebaixamento:.1%}",
                            x=0.5, y=0.5,
                            font_size=24,
                            showarrow=False
                        )
                        st.plotly_chart(fig, use_container_width=False)
                    st.markdown('</div>', unsafe_allow_html=True)

                    # Comparação com outros clubes
                    st.markdown("<br>", unsafe_allow_html=True)
                    col_table, col_radar = st.columns(2)
                    comparison_data = {
                        'Clube': ['Seu Clube', 'Média Série A', 'Clube Rebaixado Típico', 'Clube Top-4 Típico'],
                        'Plantel': [plantel, 28, 24, 32],
                        'Estrangeiros': [estrangeiros, 4, 2, 7],
                        'Valor de Mercado (M€)': [valor_mercado_total, 85, 30, 150],
                        'Risco de Rebaixamento': [prob_rebaixamento, 0.5, 0.8, 0.1]
                    }
                    comp_df = pd.DataFrame(comparison_data)
                    with col_table:
                        st.markdown("### Comparação com outros clubes")
                        st.dataframe(comp_df, hide_index=True, use_container_width=True)
                    with col_radar:
                        st.markdown("### Perfil do Clube")
                        fig_radar = px.line_polar(
                            comp_df, 
                            r=[plantel/50, estrangeiros/15, valor_mercado_total/300, 1-prob_rebaixamento], 
                            theta=['Tamanho do Elenco', 'Estrangeiros', 'Valor de Mercado', 'Segurança'],
                            line_close=True,
                            range_r=[0, 1]
                        )
                        fig_radar.update_layout(height=300)
                        st.plotly_chart(fig_radar, use_container_width=True)

    # ----------------------------------------------------------
    #  Ranking Completo de Probabilidade de Rebaixamento (2025)
    # ----------------------------------------------------------
    st.markdown("---")
    st.subheader("🏆 Ranking Completo de Probabilidade de Rebaixamento (2025)")

    # 1. Carrega parâmetros de entrada para todos os clubes a partir do arquivo Excel
    file_path = r"dados/BASE_FINAL.xlsx"
    try:
        df_parametros_2025 = pd.read_excel(file_path)
    except FileNotFoundError:
        st.error(
            f"Não foi possível encontrar '{file_path}'.\n"
            "Verifique se o arquivo existe e contém as colunas: Clube, Plantel, Estrangeiros, Valor de Mercado Total."
        )
        return

    # 2. Verifica se as colunas necessárias existem
    required_cols = {"Clube", "Plantel", "Estrangeiros", "Valor de Mercado Total"}
    if not required_cols.issubset(df_parametros_2025.columns):
        st.error(
            "O arquivo Excel deve conter exatamente as colunas:\n"
            "Clube | Plantel | Estrangeiros | Valor de Mercado Total"
        )
        return

    # 3. Chama o fazer_previsao() apenas com as 3 colunas numéricas
    previsoes_2025, probs_2025 = fazer_previsao(
        df_parametros_2025[["Plantel", "Estrangeiros", "Valor de Mercado Total"]]
    )

    # 4. Monta o DataFrame final com probabilidade e rótulo “Sim/Não”
    df_resultado_2025 = df_parametros_2025.copy()
    df_resultado_2025["Prob_Rebaixamento"] = [p[1] for p in probs_2025]
    df_resultado_2025["Rebaixado"] = df_resultado_2025["Prob_Rebaixamento"].apply(
        lambda x: "Sim" if x > 0.5 else "Não"
    )

    # 5. Ordena por probabilidade de forma decrescente
    df_sorted = df_resultado_2025.sort_values(
        by="Prob_Rebaixamento", ascending=False
    ).reset_index(drop=True)

    # 6. Converte a coluna para porcentagem arredondada
    df_sorted["Probabilidade (%)"] = (df_sorted["Prob_Rebaixamento"] * 100).round(2)

    # 7. Seleciona apenas as colunas de exibição
    df_exibir = df_sorted[["Clube", "Probabilidade (%)", "Rebaixado"]]

    # 8. Exibe o DataFrame no Streamlit
    st.dataframe(df_exibir, use_container_width=True)

    # 9. Destacar em vermelho os clubes previstos como rebaixados
    def color_red(row):
        return ["background-color: #ffe6e6"] * len(row) if row["Rebaixado"] == "Sim" else [""] * len(row)

    st.markdown("<br>", unsafe_allow_html=True)
    st.markdown("**(Times com fundo vermelho são os que o modelo prevê como rebaixados)**")
    styled = df_exibir.style.apply(color_red, axis=1)
    st.write(styled.to_html(), unsafe_allow_html=True)


if __name__ == "__main__":
    main()
# Out:
# 📉 Previsão de Rebaixamento 2025:
#                 Clube  Prob_Rebaixamento Rebaixado
# 239          Mirassol               50.7       Sim
# 238         Juventude               47.5       Sim
# 237             Ceará               35.1       Sim
# 236      Sport Recife               32.3       Sim
# 234         Fortaleza               22.3       Não
# 235           Vitória               19.9       Não
# 233        Bragantino                6.7       Não
# 232        Fluminense                4.6       Não
# 231         São Paulo                3.1       Não
# 230          Vasco da                2.3       Não
# 229             Bahia                2.0       Não
# 227  Atlético Mineiro                1.9       Não
# 228            Grêmio                1.8       Não
# 226          Cruzeiro                1.7       Não
# 225            Santos                1.4       Não
# 224     Internacional                0.5       Não
# 223       Corinthians                0.3       Não
# ...

# %%
import pandas as pd

df_resultado_2025_sorted = df_resultado_2025.sort_values(by='Prob_Rebaixamento', ascending=False).reset_index(drop=True)

df_resultado_2025_sorted['Prob_Rebaixamento'] = df_resultado_2025_sorted['Prob_Rebaixamento'] / 100

df_resultado_2025_sorted.style.format({
    'Prob_Rebaixamento': '{:.2%}'
}).applymap(lambda x: 'color: red' if isinstance(x, str) and 'Sim' in x else '', subset=['Rebaixado'])
# Out:
# C:\Users\lucia\AppData\Local\Temp\ipykernel_19032\2698453965.py:7: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df_resultado_2025_sorted.style.format({
# <style type="text/css">
# #T_d2a51_row0_col2, #T_d2a51_row1_col2, #T_d2a51_row2_col2, #T_d2a51_row3_col2 {
#   color: red;
# }
# </style>
# <table id="T_d2a51">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2a51_level0_col0" class="col_heading level0 col0" >Clube</th>
#       <th id="T_d2a51_level0_col1" class="col_heading level0 col1" >Prob_Rebaixamento</th>
#       <th id="T_d2a51_level0_col2" class="col_heading level0 col2" >Rebaixado</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2a51_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2a51_row0_col0" class="data row0 col0" >Mirassol</td>
#       <td id="T_d2a51_row0_col1" class="data row0 col1" >50.70%</td>
# ...
